# %% [markdown]
# # SAT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df_1 = pd.read_csv('project_1/data/sat_2017.csv')
df_2 = pd.read_csv('project_1/data/sat_2018.csv')
df_3 = pd.read_csv('project_1/data/sat_2019.csv')

# %%
df_sat_ca = pd.read_csv('project_1/data/sat_2019_ca.csv')

# %% [markdown]
# ## SAT 2017

# %%
df_1.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_1.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
df_1['Year'] = '2017'
df_1.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
df_1.rename(columns={'Evidence-Based Reading and Writing':'EBRW'},inplace=True)
df_1.head()
# Out:
#         State Participation  EBRW  Math  Total  Year
# 0     Alabama            5%   593   572   1165  2017
# 1      Alaska           38%   547   533   1080  2017
# 2     Arizona           30%   563   553   1116  2017
# 3    Arkansas            3%   614   594   1208  2017
# 4  California           53%   531   524   1055  2017

# %% [markdown]
# ## SAT 2018

# %%
df_2.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_2.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
df_2['Year'] = '2018'
df_2.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
df_2.rename(columns={'Evidence-Based Reading and Writing':'EBRW'},inplace=True)
df_2.head()
# Out:
#         State Participation  EBRW  Math  Total  Year
# 0     Alabama            6%   595   571   1166  2018
# 1      Alaska           43%   562   544   1106  2018
# 2     Arizona           29%   577   572   1149  2018
# 3    Arkansas            5%   592   576   1169  2018
# 4  California           60%   540   536   1076  2018

# %% [markdown]
# ## SAT 2019

# %%
df_3.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df_3.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
df_3['Year'] = '2019'
df_3.head()
# Out:
#         State Participation Rate  EBRW  Math  Total  Year
# 0     Alabama                 7%   583   560   1143  2019
# 1      Alaska                41%   556   541   1097  2019
# 2     Arizona                31%   569   565   1134  2019
# 3    Arkansas                 6%   582   559   1141  2019
# 4  California                63%   534   531   1065  2019

# %%
df_3.rename(columns = {'Participation Rate':'Participation'},inplace = True)
df_3.head()
# Out:
#         State Participation  EBRW  Math  Total  Year
# 0     Alabama            7%   583   560   1143  2019
# 1      Alaska           41%   556   541   1097  2019
# 2     Arizona           31%   569   565   1134  2019
# 3    Arkansas            6%   582   559   1141  2019
# 4  California           63%   534   531   1065  2019

# %%
df = pd.concat([df_1,df_2,df_3],ignore_index=True)
df
# Out:
#              State Participation  EBRW  Math  Total  Year
# 0          Alabama            5%   593   572   1165  2017
# 1           Alaska           38%   547   533   1080  2017
# 2          Arizona           30%   563   553   1116  2017
# 3         Arkansas            3%   614   594   1208  2017
# 4       California           53%   531   524   1055  2017
# ..             ...           ...   ...   ...    ...   ...
# 150       Virginia           68%   567   551   1119  2019
# 151     Washington           70%   539   535   1074  2019
# 152  West Virginia           99%   483   460    943  2019
# 153      Wisconsin            3%   635   648   1283  2019
# 154        Wyoming            3%   623   615   1238  2019
#
# [155 rows x 6 columns]

# %%
df[df['Participation']=='—']
# Out:
#               State Participation  EBRW  Math  Total  Year
# 141     Puerto Rico             —   483   462    944  2019
# 149  Virgin Islands             —   490   445    935  2019

# %%
df.drop(141,inplace = True)

# %%
df.drop(149,inplace = True)

# %%
df.reset_index(drop=True)
# Out:
#              State Participation  EBRW  Math  Total  Year
# 0          Alabama            5%   593   572   1165  2017
# 1           Alaska           38%   547   533   1080  2017
# 2          Arizona           30%   563   553   1116  2017
# 3         Arkansas            3%   614   594   1208  2017
# 4       California           53%   531   524   1055  2017
# ..             ...           ...   ...   ...    ...   ...
# 148       Virginia           68%   567   551   1119  2019
# 149     Washington           70%   539   535   1074  2019
# 150  West Virginia           99%   483   460    943  2019
# 151      Wisconsin            3%   635   648   1283  2019
# 152        Wyoming            3%   623   615   1238  2019
#
# [153 rows x 6 columns]

# %%
list_pert = list(df['Participation'])

# %%
def convert_percent_to_num(list):
    a = []
    for i in list:
        a.append(int(i.split('%')[0]))
    return a

# %%
convert_percent_to_num(list_pert)[:10]
# Out:
# [5, 38, 30, 3, 53, 11, 100, 100, 100, 83]

# %%
df['Participation_integer'] = convert_percent_to_num(list_pert)
df.head()
# Out:
#         State Participation  EBRW  Math  Total  Year  Participation_integer
# 0     Alabama            5%   593   572   1165  2017                      5
# 1      Alaska           38%   547   533   1080  2017                     38
# 2     Arizona           30%   563   553   1116  2017                     30
# 3    Arkansas            3%   614   594   1208  2017                      3
# 4  California           53%   531   524   1055  2017                     53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 154
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  153 non-null    object
#  1   Participation          153 non-null    object
#  2   EBRW                   153 non-null    int64
#  3   Math                   153 non-null    int64
#  4   Total                  153 non-null    int64
#  5   Year                   153 non-null    object
#  6   Participation_integer  153 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 9.6+ KB

# %%
df_parti = df.copy()

# %%
df_parti_new_sat = df_parti.set_index('State').sort_values(by='Participation_integer',ascending=False)
df_parti_new_sat
# Out:
#              Participation  EBRW  Math  Total  Year  Participation_integer
# State
# Delaware              100%   499   486    985  2019                    100
# Florida               100%   516   483    999  2019                    100
# Illinois              100%   509   504   1013  2019                    100
# Idaho                 100%   505   488    993  2019                    100
# Colorado              100%   519   506   1025  2018                    100
# ...                    ...   ...   ...    ...   ...                    ...
# North Dakota            2%   635   621   1256  2017                      2
# Mississippi             2%   634   607   1242  2017                      2
# North Dakota            2%   640   643   1283  2018                      2
# Iowa                    2%   641   635   1275  2017                      2
# North Dakota            2%   627   636   1263  2019                      2
#
# [153 rows x 6 columns]

# %%
df_parti_new_sat[df_parti_new_sat['Year']=='2017'][['Participation_integer']].head(10)
# Out:
#                       Participation_integer
# State
# Michigan                                100
# Connecticut                             100
# District of Columbia                    100
# Delaware                                100
# New Hampshire                            96
# Maine                                    95
# Idaho                                    93
# Florida                                  83
# Massachusetts                            76
# Rhode Island                             71

# %%
df_parti_new_sat[df_parti_new_sat['Year']=='2017'].loc[['California']][['Participation_integer']]
# Out:
#             Participation_integer
# State
# California                     53

# %%
dfdf = df_parti_new_sat.set_index('Year',append=1).sort_index()
dfdf.head(20)
# Out:
#                  Participation  EBRW  Math  Total  Participation_integer
# State       Year
# Alabama     2017            5%   593   572   1165                      5
#             2018            6%   595   571   1166                      6
#             2019            7%   583   560   1143                      7
# Alaska      2017           38%   547   533   1080                     38
#             2018           43%   562   544   1106                     43
#             2019           41%   556   541   1097                     41
# Arizona     2017           30%   563   553   1116                     30
#             2018           29%   577   572   1149                     29
#             2019           31%   569   565   1134                     31
# Arkansas    2017            3%   614   594   1208                      3
#             2018            5%   592   576   1169                      5
#             2019            6%   582   559   1141                      6
# ...

# %%
dif = []
for i in range(2,154,3):
    a = [dfdf.loc[dfdf.index[i][0]].loc['2019']['Participation_integer'] - dfdf.loc[dfdf.index[i][0]].loc['2017']['Participation_integer']]*3
    for j in a:
        dif.append(j)
dif[:10]
# Out:
# [2, 2, 2, 3, 3, 3, 1, 1, 1, 3]

# %%
dfdf['Diff'] = dif
dfdf['Diff'].unique()
# Out:
# array([ 2,  3,  1, 10, 89,  0, -6, 17, -1,  7, 91,  4, 13,  5, 12, 15,  8,
#        29, 18,  6, 85], dtype=int64)

# %%
dfdf.head(10)
# Out:
#               Participation  EBRW  Math  Total  Participation_integer  Diff
# State    Year
# Alabama  2017            5%   593   572   1165                      5     2
#          2018            6%   595   571   1166                      6     2
#          2019            7%   583   560   1143                      7     2
# Alaska   2017           38%   547   533   1080                     38     3
#          2018           43%   562   544   1106                     43     3
#          2019           41%   556   541   1097                     41     3
# Arizona  2017           30%   563   553   1116                     30     1
#          2018           29%   577   572   1149                     29     1
#          2019           31%   569   565   1134                     31     1
# Arkansas 2017            3%   614   594   1208                      3     3

# %%
dfdf_2 = dfdf.reset_index()
dfdf_3 = dfdf_2[dfdf_2['Year']=='2019'].sort_values(by='Participation_integer',ascending=False).set_index('State')
dfdf_3.head(10)
# Out:
#                Year Participation  EBRW  Math  Total  Participation_integer  \
# State
# Rhode Island   2019          100%   503   492    995                    100
# Illinois       2019          100%   509   504   1013                    100
# Michigan       2019          100%   507   496   1003                    100
# Colorado       2019          100%   518   506   1024                    100
# Connecticut    2019          100%   529   516   1046                    100
# Delaware       2019          100%   499   486    985                    100
# Florida        2019          100%   516   483    999                    100
# Idaho          2019          100%   505   488    993                    100
# Maine          2019           99%   512   502   1013                     99
# West Virginia  2019           99%   483   460    943                     99
#
#                Diff
# State
# Rhode Island     29
# Illinois         91
# Michigan          0
# Colorado         89
# ...

# %%
dfdf_calif = dfdf_3.loc[['California']]
dfdf_calif
# Out:
#             Year Participation  EBRW  Math  Total  Participation_integer  Diff
# State
# California  2019           63%   534   531   1065                     63    10

# %%
dfdf_2 = dfdf.reset_index()
dfdf_4 = dfdf_2[dfdf_2['Year']=='2019'].sort_values(by='Diff',ascending=False).set_index('State')
dfdf_4.head(10)
# Out:
#                 Year Participation  EBRW  Math  Total  Participation_integer  \
# State
# Illinois        2019          100%   509   504   1013                    100
# Colorado        2019          100%   518   506   1024                    100
# West Virginia   2019           99%   483   460    943                     99
# Rhode Island    2019          100%   503   492    995                    100
# South Carolina  2019           68%   526   504   1030                     68
# Florida         2019          100%   516   483    999                    100
# Oklahoma        2019           22%   490   472    963                     22
# Maryland        2019           82%   535   523   1058                     82
# New York        2019           79%   531   533   1064                     79
# New Jersey      2019           82%   544   545   1090                     82
#
#                 Diff
# State
# Illinois          91
# Colorado          89
# West Virginia     85
# ...

# %%
pd.concat([dfdf_3['Participation_integer'].head(10),dfdf_calif['Participation_integer']],axis=1).plot(kind='bar',figsize=(8,4),fontsize=12,width=1,legend=False)
plt.xlabel('State',fontsize=12)
plt.ylabel('Participation (%)',fontsize=12)
plt.title('SAT : Top 10 states %Participation in 2019',fontsize=15)
plt.xticks(rotation=60);

# %%
pd.concat([dfdf_4['Diff'].head(10),dfdf_calif['Diff']],axis=1).plot(kind='bar',figsize=(8,4),fontsize=12,width=1,legend=False)
plt.xlabel('State',fontsize=12)
plt.ylabel('Participation (%)',fontsize=12)
plt.title('SAT : Top 10 states %Change between 2017 and 2019',fontsize=15)
plt.xticks(rotation=60);

# %%
pd.concat([dfdf_3['Diff'].tail(10),dfdf_calif['Diff']],axis=1).plot(kind='bar',figsize=(8,4),fontsize=12,width=1,legend=False)
plt.xlabel('State',fontsize=12)
plt.ylabel('Participation (%)',fontsize=12)
plt.title('SAT : The last 10 states %Participation in 2019',fontsize=15)
plt.xticks(rotation=60);

# %%
pd.concat([dfdf_4['Diff'].tail(10),dfdf_calif['Diff']],axis=1).plot(kind='bar',figsize=(8,4),fontsize=12,width=1,legend=False)
plt.xlabel('State',fontsize=12)
plt.ylabel('Participation (%)',fontsize=12)
plt.title('SAT : The last 10 states %Change between 2017 and 2019',fontsize=15)
plt.xticks(rotation=60);

# %%
df_parti_new.set_index('Year',append=1).sort_index().loc[['California']][['Participation_integer']].plot(kind='line',legend=False,figsize=(6,5),lw=3,color='salmon',fontsize=12);
plt.title('SAT : Trend of participation of California in 3 Years');
plt.ylabel('Percent of Participation (%)');

# %%
pd.concat([df_parti_new_sat[df_parti_new_sat['Year']=='2017'][['Participation_integer']].head(10),df_parti_new_sat[df_parti_new_sat['Year']=='2017'].loc[['California']][['Participation_integer']]],axis=1).plot(kind='bar',legend=False,figsize=(8,4),width=1);
plt.title('SAT : Top 10 of Percent of Participation (2017)');
plt.ylabel('Percent of Participation (%)');
plt.xticks(rotation=60);

# %%
pd.concat([df_parti_new[df_parti_new['Year']=='2018'][['Participation_integer']].head(10),df_parti_new[df_parti_new['Year']=='2018'].loc[['California']][['Participation_integer']]],axis=1).plot(kind='bar',legend=False,figsize=(8,4),width=1);
plt.title('SAT : Top 10 of Percent of Participation (2018)');
plt.ylabel('Percent of Participation (%)');
plt.xticks(rotation=60);

# %%
pd.concat([df_parti_new_sat[df_parti_new_sat['Year']=='2019'][['Participation_integer']].head(10),df_parti_new_sat[df_parti_new_sat['Year']=='2019'].loc[['California']][['Participation_integer']]],axis=1).plot(kind='bar',legend=False,figsize=(8,4),width=1);
plt.title('SAT : Top 10 of Percent of Participation (2019)');
plt.ylabel('Percent of Participation (%)');
plt.xticks(rotation=60);

# %% [markdown]
# ## World Map

# %%
# !pip install chart_studio

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go #importing graphical objects
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
    
data = dict(type='choropleth',
            locations = dfdf_dic['Abbreviation'],
            locationmode = 'USA-states',
            colorscale = 'Viridis',
            text = dfdf_dic['State'],
            z = dfdf_dic['Diff'],
            colorbar = {'title':"SAT : %Change Between 2017 and 2019"},
            zmin=0, zmax=10, marker_line_width=0.2)

layout = dict(title = 'SAT %Change between 2017 and 2019',
              geo = dict(scope='usa'))

choromap = go.Figure(data = [data],layout = layout)
choromap.update_layout(mapbox_style="light",mapbox_zoom=3, mapbox_center = {"lat": 37.0902, "lon": -95.7129})
iplot(choromap)
# Out:
# <div>                            <div id="629e40f9-6741-4795-a474-56993a12166e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("629e40f9-6741-4795-a474-56993a12166e")) {                    Plotly.newPlot(                        "629e40f9-6741-4795-a474-56993a12166e",                        [{"colorbar": {"title": {"text": "SAT : %Change Between 2017 and 2019"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "locationmode": "USA-states", "locations": ["AL", "AL", "AL", "AK", "AK", "AK"
# ...

# %%
dic = pd.read_csv('Abbreviation.csv')
dic.head()
# Out:
#             State Abbreviation
# 0         Alabama           AL
# 1          Alaska           AK
# 2  American Samoa           AS
# 3         Arizona           AZ
# 4        Arkansas           AR

# %%
dfdf_dic = pd.merge(dfdf_2,dic,left_on='State',right_on='State',how='left')

# %%
dfdf_dic_2 = dfdf_dic.fillna('RI')

# %% [markdown]
# ## Visualization

# %%
mean_EBRW_2017 = df[df['Year']=='2017']['EBRW'].mean()
sd_EBRW_2017 = df[df['Year']=='2017']['EBRW'].std()
sns.distplot(df[df['Year']=='2017']['EBRW'],bins=20,color = '#EC7063')
plt.axvline(df[df['Year']=='2017']['EBRW'].mean(),linewidth=3,linestyle='--')
plt.title(f'EBRW in 2017 (mean = {mean_EBRW_2017:.2f}, sd = {sd_EBRW_2017:.2f})')
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_EBRW_2018 = df[df['Year']=='2018']['EBRW'].mean()
sd_EBRW_2018 = df[df['Year']=='2018']['EBRW'].std()
sns.distplot(df[df['Year']=='2018']['EBRW'],bins=20,color = '#D4AC0D')
plt.axvline(df.EBRW.mean(),linewidth=3,linestyle='--')
plt.title(f'EBRW in 2018 (mean = {mean_EBRW_2018:.2f}, sd = {sd_EBRW_2018:.2f})')
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_EBRW_2019 = df[df['Year']=='2019']['EBRW'].mean()
sd_EBRW_2019 = df[df['Year']=='2019']['EBRW'].std()
sns.distplot(df[df['Year']=='2019']['EBRW'],bins=20,color = '#148F77')

plt.axvline(df.EBRW.mean(),linewidth=3,linestyle='--',label='mean')
plt.axvline(df[(df['State']=='California')&(df['Year']=='2019')]['EBRW'].max(),
            linewidth=3,linestyle='--',label='California',color='r')

plt.title(f'EBRW in 2019 (mean = {mean_EBRW_2019:.2f}, sd = {sd_EBRW_2019:.2f})')
plt.legend()
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(df[df['Year']=='2017']['EBRW'],bins=20,color = '#EC7063',hist=False,label='2017')
sns.distplot(df[df['Year']=='2018']['EBRW'],bins=20,color = '#D4AC0D',hist=False,label='2018')
sns.distplot(df[df['Year']=='2019']['EBRW'],bins=20,color = '#148F77',hist=False,label='2019')
plt.axvline(df.EBRW.mean(),linewidth=3,linestyle='--',label='mean')
plt.legend()
plt.title('Comparative EBRW in 3 Years')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %%
mean_Math_2017 = df[df['Year']=='2017']['Math'].mean()
sd_Math_2017 = df[df['Year']=='2017']['Math'].std()
sns.distplot(df[df['Year']=='2017']['Math'],bins=20,color = '#EC7063')
plt.axvline(df.Math.mean(),linewidth=3,linestyle='--')
plt.title(f'Math in 2017 (mean = {mean_Math_2017:.2f}, sd = {sd_Math_2017:.2f})')
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_Math_2018 = df[df['Year']=='2018']['Math'].mean()
sd_Math_2018 = df[df['Year']=='2018']['Math'].std()
sns.distplot(df[df['Year']=='2018']['Math'],bins=20,color = '#D4AC0D')
plt.axvline(df.Math.mean(),linewidth=3,linestyle='--')
plt.title(f'Math in 2018 (mean = {mean_Math_2018:.2f}, sd = {sd_Math_2018:.2f})')
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_Math_2019 = df[df['Year']=='2019']['Math'].mean()
sd_Math_2019 = df[df['Year']=='2019']['Math'].std()
sns.distplot(df[df['Year']=='2019']['Math'],bins=20,color = '#148F77')

plt.axvline(df.Math.mean(),linewidth=3,linestyle='--',label='mean')
plt.axvline(df[(df['State']=='California')&(df['Year']=='2019')]['Math'].max(),
            linewidth=3,linestyle='--',label='California',color='r')

plt.title(f'Math in 2019 (mean = {mean_Math_2019:.2f}, sd = {sd_Math_2019:.2f})')
plt.legend()
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(df[df['Year']=='2017']['Math'],bins=20,color = '#EC7063',hist=False,label='2017')
sns.distplot(df[df['Year']=='2018']['Math'],bins=20,color = '#D4AC0D',hist=False,label='2018')
sns.distplot(df[df['Year']=='2019']['Math'],bins=20,color = '#148F77',hist=False,label='2019')
plt.axvline(df.Math.mean(),linewidth=3,linestyle='--',label='mean')
plt.legend()
plt.title('Comparative Math in 3 Years')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %%
mean_Total_2017 = df[df['Year']=='2017']['Total'].mean()
sd_Total_2017 = df[df['Year']=='2017']['Total'].std()
sns.distplot(df[df['Year']=='2017']['Total'],bins=10,color = '#EC7063')
plt.axvline(df.Total.mean(),linewidth=3,linestyle='--')
plt.title(f'Total in 2017 (mean = {mean_Total_2017:.2f}, sd = {sd_Total_2017:.2f})')
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_Total_2018 = df[df['Year']=='2018']['Total'].mean()
sd_Total_2018 = df[df['Year']=='2018']['Total'].std()
sns.distplot(df[df['Year']=='2018']['Total'],bins=10,color = '#D4AC0D')
plt.axvline(df.Total.mean(),linewidth=3,linestyle='--',label='mean')
plt.title(f'Total in 2018 (mean = {mean_Total_2018:.2f}, sd = {sd_Total_2018:.2f})')
plt.legend()
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
mean_Total_2019 = df[df['Year']=='2019']['Total'].mean()
sd_Total_2019 = df[df['Year']=='2019']['Total'].std()
cali_Total = df[(df['State']=='California')&(df['Year']=='2019')]['Total'].mean()
sns.distplot(df[df['Year']=='2019']['Total'],bins=20,color = '#148F77')

plt.axvline(df.Total.mean(),linewidth=3,linestyle='--',label='mean')
plt.axvline(df[(df['State']=='California')&(df['Year']=='2019')]['Total'].max(),
            linewidth=3,linestyle='--',label='California',color='r')

print(f'California Score = {cali_Total}')
plt.title(f'Total in 2019 (mean = {mean_Total_2019:.2f}, sd = {sd_Total_2019:.2f})')
plt.legend()
plt.grid()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# California Score = 1065.0

# %%
df[(df['State']=='California')&(df['Year']=='2019')]['Total'].max()
# Out:
# 1065

# %%
df.Total.mean()
# Out:
# 1119.7320261437908

# %%
sns.distplot(df[df['Year']=='2017']['Total'],bins=20,color = '#EC7063',hist=False,label='2017');
sns.distplot(df[df['Year']=='2018']['Total'],bins=20,color = '#D4AC0D',hist=False,label='2018');
sns.distplot(df[df['Year']=='2019']['Total'],bins=20,color = '#148F77',hist=False,label='2019');
plt.axvline(df.Total.mean(),linewidth=3,linestyle='--',label='mean')
plt.legend()
plt.title('Comparative Total in 3 Years')
print(df.Total.mean())
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# ...

# %%
df.head()
# Out:
#         State Participation  EBRW  Math  Total  Year  Participation_integer
# 0     Alabama            5%   593   572   1165  2017                   0.05
# 1      Alaska           38%   547   533   1080  2017                   0.38
# 2     Arizona           30%   563   553   1116  2017                   0.30
# 3    Arkansas            3%   614   594   1208  2017                   0.03
# 4  California           53%   531   524   1055  2017                   0.53

# %%
df_sat_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
df_sat_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
df_sat_ca.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12', 'PctERWBenchmark12',
#        'NumMathBenchmark12', 'PctMathBenchmark12', 'Enroll11', 'NumTSTTakr11',
#        'NumERWBenchmark11', 'PctERWBenchmark11', 'NumMathBenchmark11',
#        'PctMathBenchmark11', 'TotNumBothBenchmark12', 'PctBothBenchmark12',
#        'TotNumBothBenchmark11', 'PctBothBenchmark11', 'Year', 'Unnamed: 25'],
#       dtype='object')

# %%
df_sat_ca.drop(['CDS', 'CCode', 'CDCode', 'SCode','Year', 'Unnamed: 25'],axis=1,inplace=True)

# %%
df_sat_ca = df_sat_ca[df_sat_ca['RType']=='C']
df_sat_ca.head()
# Out:
#      RType SName DName        CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 1981     C   NaN   NaN    El Dorado    2226.0         604.0               547
# 1982     C   NaN   NaN  Los Angeles  114618.0       48676.0             30081
# 1983     C   NaN   NaN       Madera    2352.0         442.0               277
# 1984     C   NaN   NaN         Yolo    2299.0         759.0               586
# 1985     C   NaN   NaN         Kern   14229.0        3793.0              2334
#
#      PctERWBenchmark12 NumMathBenchmark12 PctMathBenchmark12  Enroll11  \
# 1981             90.56                458              75.83    2201.0
# 1982             61.80              19791              40.66  111894.0
# 1983             62.67                136              30.77    2318.0
# 1984             77.21                464              61.13    2320.0
# 1985             61.53               1481              39.05   13967.0
#
# ...

# %%
df_sat_ca.drop(['RType','SName','DName'],axis=1,inplace=True)

# %%
df_sat_ca.shape
# Out:
# (58, 17)

# %%
df_sat_ca.isnull().sum()
# Out:
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        1
# PctERWBenchmark12        1
# NumMathBenchmark12       1
# PctMathBenchmark12       1
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        1
# PctERWBenchmark11        1
# NumMathBenchmark11       1
# PctMathBenchmark11       1
# TotNumBothBenchmark12    1
# PctBothBenchmark12       1
# TotNumBothBenchmark11    1
# PctBothBenchmark11       1
# dtype: int64

# %%
df_sat_ca[df_sat_ca['NumERWBenchmark12']=='*'].shape
# Out:
# (2, 17)

# %%
df_sat_ca_update = df_sat_ca[df_sat_ca['NumERWBenchmark12'].notnull()]
df_sat_ca_update.isnull().sum()
# Out:
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# dtype: int64

# %%
df_sat_ca_update = df_sat_ca_update[df_sat_ca_update['NumERWBenchmark11'].notnull()]
df_sat_ca_update.isnull().sum()
# Out:
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# dtype: int64

# %%
df_sat_ca_update.reset_index(drop=True,inplace=True)

# %%
df_sat_ca_update.isnull().sum()
# Out:
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# dtype: int64

# %%
df_sat_ca_update
# Out:
#               CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0         El Dorado    2226.0         604.0               547
# 1       Los Angeles  114618.0       48676.0             30081
# 2            Madera    2352.0         442.0               277
# 3              Yolo    2299.0         759.0               586
# 4              Kern   14229.0        3793.0              2334
# 5              Napa    1717.0         555.0               403
# 6        Santa Cruz    3239.0         864.0               655
# 7            Sierra      23.0           5.0                 *
# 8        Sacramento   19540.0        6090.0              4138
# 9    San Bernardino   31635.0       10544.0              7014
# 10        Calaveras     451.0          90.0                81
# 11         Mariposa     155.0          36.0                33
# 12           Placer    5931.0        1959.0              1709
# 13         Tuolumne     518.0          80.0                66
# ...

# %%
### จำนวน row ที่มี * เท่ากัน แต่จริงๆแล้วคนละ row กัน
print(df_sat_ca_update[df_sat_ca_update['NumERWBenchmark11']=='*'].shape)
print(df_sat_ca_update[df_sat_ca_update['NumERWBenchmark12']=='*'].shape)
# Out:
# (2, 17)
# (2, 17)

# %%
df_sat_ca_update.columns
# Out:
# Index(['CName', 'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12',
#        'PctERWBenchmark12', 'NumMathBenchmark12', 'PctMathBenchmark12',
#        'Enroll11', 'NumTSTTakr11', 'NumERWBenchmark11', 'PctERWBenchmark11',
#        'NumMathBenchmark11', 'PctMathBenchmark11', 'TotNumBothBenchmark12',
#        'PctBothBenchmark12', 'TotNumBothBenchmark11', 'PctBothBenchmark11'],
#       dtype='object')

# %% [markdown]
# ### G11

# %%
### เนื่องจากเหตุผลด้านบนจึงทำการแยก Grade 11&12 ออกจากกันก่อน
df_sat_g11 = df_sat_ca_update[['CName','Enroll11', 'NumTSTTakr11', 'NumERWBenchmark11',
       'PctERWBenchmark11', 'NumMathBenchmark11', 'PctMathBenchmark11','TotNumBothBenchmark11',
       'PctBothBenchmark11']]
df_sat_g11
# Out:
#               CName  Enroll11  NumTSTTakr11 NumERWBenchmark11  \
# 0         El Dorado    2201.0         713.0               667
# 1       Los Angeles  111894.0       68275.0             39363
# 2            Madera    2318.0        1290.0               608
# 3              Yolo    2320.0         798.0               709
# 4              Kern   13967.0        2789.0              2077
# 5              Napa    1687.0         778.0               576
# 6        Santa Cruz    3078.0        1049.0               873
# 7            Sierra      31.0          14.0                 *
# 8        Sacramento   18106.0        7684.0              5418
# 9    San Bernardino   31049.0       16105.0              9602
# 10        Calaveras     450.0         106.0                93
# 11         Mariposa     136.0          39.0                35
# 12           Placer    5919.0        2147.0              1996
# 13         Tuolumne     493.0          68.0                60
# ...

# %%
df_sat_g11_update = df_sat_g11[df_sat_g11['NumERWBenchmark11']!='*']

# %%
df_sat_g11_update.reset_index(drop=True,inplace=True)
print(df_sat_g11_update.shape)
df_sat_g11_update
# Out:
# (55, 9)
#               CName  Enroll11  NumTSTTakr11 NumERWBenchmark11  \
# 0         El Dorado    2201.0         713.0               667
# 1       Los Angeles  111894.0       68275.0             39363
# 2            Madera    2318.0        1290.0               608
# 3              Yolo    2320.0         798.0               709
# 4              Kern   13967.0        2789.0              2077
# 5              Napa    1687.0         778.0               576
# 6        Santa Cruz    3078.0        1049.0               873
# 7        Sacramento   18106.0        7684.0              5418
# 8    San Bernardino   31049.0       16105.0              9602
# 9         Calaveras     450.0         106.0                93
# 10         Mariposa     136.0          39.0                35
# 11           Placer    5919.0        2147.0              1996
# 12         Tuolumne     493.0          68.0                60
# 13        Mendocino     995.0         237.0               177
# ...

# %%
df_sat_g11_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CName                  55 non-null     object
#  1   Enroll11               55 non-null     float64
#  2   NumTSTTakr11           55 non-null     float64
#  3   NumERWBenchmark11      55 non-null     object
#  4   PctERWBenchmark11      55 non-null     object
#  5   NumMathBenchmark11     55 non-null     object
#  6   PctMathBenchmark11     55 non-null     object
#  7   TotNumBothBenchmark11  55 non-null     object
#  8   PctBothBenchmark11     55 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 4.0+ KB

# %%
df_sat_g11_update.columns
# Out:
# Index(['CName', 'Enroll11', 'NumTSTTakr11', 'NumERWBenchmark11',
#        'PctERWBenchmark11', 'NumMathBenchmark11', 'PctMathBenchmark11',
#        'TotNumBothBenchmark11', 'PctBothBenchmark11'],
#       dtype='object')

# %%
df_sat_g11_update[['PctERWBenchmark11','PctMathBenchmark11','PctBothBenchmark11']] = df_sat_g11_update[['PctERWBenchmark11','PctMathBenchmark11','PctBothBenchmark11']].astype('float')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_sat_g11_update[['Enroll11', 'NumTSTTakr11','NumERWBenchmark11','NumMathBenchmark11','TotNumBothBenchmark11']] = df_sat_g11_update[['Enroll11', 'NumTSTTakr11','NumERWBenchmark11','NumMathBenchmark11','TotNumBothBenchmark11']].astype('int')

# %%
df_sat_g11_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CName                  55 non-null     object
#  1   Enroll11               55 non-null     int32
#  2   NumTSTTakr11           55 non-null     int32
#  3   NumERWBenchmark11      55 non-null     int32
#  4   PctERWBenchmark11      55 non-null     float64
#  5   NumMathBenchmark11     55 non-null     int32
#  6   PctMathBenchmark11     55 non-null     float64
#  7   TotNumBothBenchmark11  55 non-null     int32
#  8   PctBothBenchmark11     55 non-null     float64
# dtypes: float64(3), int32(5), object(1)
# memory usage: 2.9+ KB

# %%
df_sat_g11_update.head()
# Out:
#          CName  Enroll11  NumTSTTakr11  NumERWBenchmark11  PctERWBenchmark11  \
# 0    El Dorado      2201           713                667              93.55
# 1  Los Angeles    111894         68275              39363              57.65
# 2       Madera      2318          1290                608              47.13
# 3         Yolo      2320           798                709              88.85
# 4         Kern     13967          2789               2077              74.47
#
#    NumMathBenchmark11  PctMathBenchmark11  TotNumBothBenchmark11  \
# 0                 636               89.20                    619
# 1               26064               38.18                  24602
# 2                 316               24.50                    293
# 3                 605               75.81                    591
# 4                1570               56.29                   1454
#
#    PctBothBenchmark11
# 0               86.82
# 1               36.03
# 2               22.71
# ...

# %%
df_sat_g11_update_cname_1 = df_sat_g11_update[['CName', 'Enroll11', 'NumTSTTakr11','NumERWBenchmark11','NumMathBenchmark11','TotNumBothBenchmark11']]
df_sat_g11_update_cname_1 = df_sat_g11_update_cname_1.groupby('CName').sum()
print(len(df_sat_g11_update_cname_1))
df_sat_g11_update_cname_1.head()
# Out:
# 55
#            Enroll11  NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  \
# CName
# Alameda       17191          7608               6374                5607
# Amador          344            48                 47                  41
# Butte          2392           536                466                 413
# Calaveras       450           106                 93                  74
# Colusa          367           114                 78                  57
#
#            TotNumBothBenchmark11
# CName
# Alameda                     5437
# Amador                        41
# Butte                        394
# Calaveras                     70
# Colusa                        54

# %%
### ค่าเฉลี่ยของคะแนนของ g11 แยกตามเมือง
df_sat_g11_update_cname_2 = df_sat_g11_update[['CName', 'PctERWBenchmark11',
       'PctMathBenchmark11', 'PctBothBenchmark11']]
df_sat_g11_update_cname_2 = df_sat_g11_update_cname_2.groupby('CName').mean().apply(lambda x:np.round(x,2))
print(len(df_sat_g11_update_cname_2))
df_sat_g11_update_cname_2.head()
# Out:
# 55
#            PctERWBenchmark11  PctMathBenchmark11  PctBothBenchmark11
# CName
# Alameda                83.78               73.70               71.46
# Amador                 97.92               85.42               85.42
# Butte                  86.94               77.05               73.51
# Calaveras              87.74               69.81               66.04
# Colusa                 68.42               50.00               47.37

# %%
### นำมา concatinate กัน
df_sat_g11_cname = pd.concat([df_sat_g11_update_cname_1,df_sat_g11_update_cname_2],axis=1)
df_sat_g11_cname
# Out:
#                  Enroll11  NumTSTTakr11  NumERWBenchmark11  \
# CName
# Alameda             17191          7608               6374
# Amador                344            48                 47
# Butte                2392           536                466
# Calaveras             450           106                 93
# Colusa                367           114                 78
# Contra Costa        14120          5157               4583
# Del Norte             297            66                 51
# El Dorado            2201           713                667
# Fresno              14965          6291               3886
# Glenn                 439            90                 67
# Humboldt             1235           297                245
# Imperial             2890           626                460
# Inyo                  881            81                 49
# Kern                13967          2789               2077
# Kings                2238           364                264
# ...

# %%
df_sat_g11_cname['Percent_Test_Takers'] = np.round((df_sat_g11_cname['NumTSTTakr11']/df_sat_g11_cname['Enroll11'])*100,2)

# %%
df_sat_g11_cname.head()
# Out:
#            Enroll11  NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  \
# CName
# Alameda       17191          7608               6374                5607
# Amador          344            48                 47                  41
# Butte          2392           536                466                 413
# Calaveras       450           106                 93                  74
# Colusa          367           114                 78                  57
#
#            TotNumBothBenchmark11  PctERWBenchmark11  PctMathBenchmark11  \
# CName
# Alameda                     5437              83.78               73.70
# Amador                        41              97.92               85.42
# Butte                        394              86.94               77.05
# Calaveras                     70              87.74               69.81
# Colusa                        54              68.42               50.00
#
#            PctBothBenchmark11  Percent_Test_Takers
# CName
# ...

# %%
df_sat_g11_cname.columns
# Out:
# Index(['Enroll11', 'NumTSTTakr11', 'NumERWBenchmark11', 'NumMathBenchmark11',
#        'TotNumBothBenchmark11', 'PctERWBenchmark11', 'PctMathBenchmark11',
#        'PctBothBenchmark11', 'Percent_Test_Takers'],
#       dtype='object')

# %%
### Top 10 of Percent of Test Takers Grade 11 in each State
sns.set_style('whitegrid')
df_sat_g11_cname['Percent_Test_Takers'].sort_values(ascending=False)[:10].plot(kind='bar',figsize=(10,5),color='salmon',fontsize=12)
plt.title('G11 : Top 10 of Percent of Test Takers in each City\n',fontsize=15)
plt.xlabel('City Name')
plt.ylabel('Percent of Test Takers')
plt.xticks(rotation=30);

# %%
df_sat_g11_cname_top10 = df_sat_g11_cname.sort_values(by ='Percent_Test_Takers', ascending=False)[:10]
df_sat_g11_cname_top10.head()
# Out:
#                 Enroll11  NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  \
# CName
# Santa Clara        20501         13736              10654                8948
# Los Angeles       111894         68275              39363               26064
# Madera              2318          1290                608                 316
# San Bernardino     31049         16105               9602                5952
# Ventura            10924          5468               3565                2697
#
#                 TotNumBothBenchmark11  PctERWBenchmark11  PctMathBenchmark11  \
# CName
# Santa Clara                      8651              77.56               65.14
# Los Angeles                     24602              57.65               38.18
# Madera                            293              47.13               24.50
# San Bernardino                   5577              59.62               36.96
# Ventura                          2580              65.20               49.32
#
# ...

# %%
avg_per_top10_g11 = df_sat_g11_cname_top10.PctBothBenchmark11.mean()
avg_per_top10_g11
# Out:
# 49.897999999999996

# %%
df_sat_g11_cname_top10[['NumERWBenchmark11','NumMathBenchmark11','TotNumBothBenchmark11']].plot(kind='bar',figsize=(12,5),fontsize=10)
plt.ylabel('Number of Test Takers')
plt.title('G11 : Summary Top 10 of Test Takers(%) in California\n',fontsize=15)
plt.xticks(rotation=30);

# %%
df_sat_g11_cname_top10[['PctERWBenchmark11', 'PctMathBenchmark11','PctBothBenchmark11']].plot(kind='bar',figsize=(12,5),fontsize=10)
plt.axhline(avg_per_top10_g11,color='r',lw=2,linestyle='--',alpha=0.6,label='Mean of PctBothBenchmark11')
plt.ylabel('Percent of Test Takers (%)')
plt.xticks(rotation=30);
plt.title('G11 : Summary Top 10 of Test Takers(%) by SAT score in California\n',fontsize=15)
plt.legend();

# %% [markdown]
# ### G12

# %%
df_sat_g12 = df_sat_ca_update[['CName','Enroll12', 'NumTSTTakr12',
       'NumERWBenchmark12', 'PctERWBenchmark12', 'NumMathBenchmark12',
       'PctMathBenchmark12','TotNumBothBenchmark12', 'PctBothBenchmark12']]
df_sat_g12
# Out:
#               CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0         El Dorado    2226.0         604.0               547
# 1       Los Angeles  114618.0       48676.0             30081
# 2            Madera    2352.0         442.0               277
# 3              Yolo    2299.0         759.0               586
# 4              Kern   14229.0        3793.0              2334
# 5              Napa    1717.0         555.0               403
# 6        Santa Cruz    3239.0         864.0               655
# 7            Sierra      23.0           5.0                 *
# 8        Sacramento   19540.0        6090.0              4138
# 9    San Bernardino   31635.0       10544.0              7014
# 10        Calaveras     451.0          90.0                81
# 11         Mariposa     155.0          36.0                33
# 12           Placer    5931.0        1959.0              1709
# 13         Tuolumne     518.0          80.0                66
# ...

# %%
df_sat_g12_update = df_sat_g12[df_sat_g12['NumERWBenchmark12']!='*']

# %%
df_sat_g12_update.reset_index(drop=True,inplace=True)
print(df_sat_g12_update.shape)
#print(df_sat_ca.shape)
df_sat_g12_update
# Out:
# (55, 9)
#               CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0         El Dorado    2226.0         604.0               547
# 1       Los Angeles  114618.0       48676.0             30081
# 2            Madera    2352.0         442.0               277
# 3              Yolo    2299.0         759.0               586
# 4              Kern   14229.0        3793.0              2334
# 5              Napa    1717.0         555.0               403
# 6        Santa Cruz    3239.0         864.0               655
# 7        Sacramento   19540.0        6090.0              4138
# 8    San Bernardino   31635.0       10544.0              7014
# 9         Calaveras     451.0          90.0                81
# 10         Mariposa     155.0          36.0                33
# 11           Placer    5931.0        1959.0              1709
# 12         Tuolumne     518.0          80.0                66
# 13        Mendocino     988.0         217.0               174
# ...

# %%
df_sat_g12_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CName                  55 non-null     object
#  1   Enroll12               55 non-null     float64
#  2   NumTSTTakr12           55 non-null     float64
#  3   NumERWBenchmark12      55 non-null     object
#  4   PctERWBenchmark12      55 non-null     object
#  5   NumMathBenchmark12     55 non-null     object
#  6   PctMathBenchmark12     55 non-null     object
#  7   TotNumBothBenchmark12  55 non-null     object
#  8   PctBothBenchmark12     55 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 4.0+ KB

# %%
df_sat_g12_update.columns
# Out:
# Index(['CName', 'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12',
#        'PctERWBenchmark12', 'NumMathBenchmark12', 'PctMathBenchmark12',
#        'TotNumBothBenchmark12', 'PctBothBenchmark12'],
#       dtype='object')

# %%
df_sat_g12_update[['PctERWBenchmark12','PctMathBenchmark12','PctBothBenchmark12']] = df_sat_g12_update[['PctERWBenchmark12','PctMathBenchmark12','PctBothBenchmark12']].astype('float')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_sat_g12_update[['Enroll12', 'NumTSTTakr12','NumERWBenchmark12','NumMathBenchmark12','TotNumBothBenchmark12']] = df_sat_g12_update[['Enroll12', 'NumTSTTakr12','NumERWBenchmark12','NumMathBenchmark12','TotNumBothBenchmark12']].astype('int')

# %%
df_sat_g12_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CName                  55 non-null     object
#  1   Enroll12               55 non-null     int32
#  2   NumTSTTakr12           55 non-null     int32
#  3   NumERWBenchmark12      55 non-null     int32
#  4   PctERWBenchmark12      55 non-null     float64
#  5   NumMathBenchmark12     55 non-null     int32
#  6   PctMathBenchmark12     55 non-null     float64
#  7   TotNumBothBenchmark12  55 non-null     int32
#  8   PctBothBenchmark12     55 non-null     float64
# dtypes: float64(3), int32(5), object(1)
# memory usage: 2.9+ KB

# %%
### จำแนกตามเมืองว่าแต่ละเมืองมีค่าเฉลี่ยของคะแนนเท่าไหร่บ้าง
df_sat_g12_update#.groupby('CName').mean()#.apply(lambda x:np.round(x,2))
# Out:
#               CName  Enroll12  NumTSTTakr12  NumERWBenchmark12  \
# 0         El Dorado      2226           604                547
# 1       Los Angeles    114618         48676              30081
# 2            Madera      2352           442                277
# 3              Yolo      2299           759                586
# 4              Kern     14229          3793               2334
# 5              Napa      1717           555                403
# 6        Santa Cruz      3239           864                655
# 7        Sacramento     19540          6090               4138
# 8    San Bernardino     31635         10544               7014
# 9         Calaveras       451            90                 81
# 10         Mariposa       155            36                 33
# 11           Placer      5931          1959               1709
# 12         Tuolumne       518            80                 66
# 13        Mendocino       988           217                174
# ...

# %%
### ผลรวมของ g12 แยกตามเมือง
df_sat_g12_update_cname_1 = df_sat_g12_update[['CName', 'Enroll12', 'NumTSTTakr12','NumERWBenchmark12','NumMathBenchmark12','TotNumBothBenchmark12']]
df_sat_g12_update_cname_1 = df_sat_g12_update_cname_1.groupby('CName').sum()
print(len(df_sat_g12_update_cname_1))
df_sat_g12_update_cname_1.head()
# Out:
# 55
#            Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  \
# CName
# Alameda       17567          5946               4566                3623
# Amador          305            53                 44                  35
# Butte          2551           551                453                 349
# Calaveras       451            90                 81                  60
# Colusa          339            74                 39                  15
#
#            TotNumBothBenchmark12
# CName
# Alameda                     3458
# Amador                        33
# Butte                        332
# Calaveras                     60
# Colusa                        14

# %%
### ค่าเฉลี่ยของคะแนนของ g12 แยกตามเมือง
df_sat_g12_update_cname_2 = df_sat_g12_update[['CName', 'PctERWBenchmark12',
       'PctMathBenchmark12', 'PctBothBenchmark12']]
df_sat_g12_update_cname_2 = df_sat_g12_update_cname_2.groupby('CName').mean().apply(lambda x:np.round(x,2))
print(len(df_sat_g12_update_cname_2))
df_sat_g12_update_cname_2.head()
# Out:
# 55
#            PctERWBenchmark12  PctMathBenchmark12  PctBothBenchmark12
# CName
# Alameda                76.79               60.93               58.16
# Amador                 83.02               66.04               62.26
# Butte                  82.21               63.34               60.25
# Calaveras              90.00               66.67               66.67
# Colusa                 52.70               20.27               18.92

# %%
### นำมา concatinate กัน
df_sat_g12_cname = pd.concat([df_sat_g12_update_cname_1,df_sat_g12_update_cname_2],axis=1)
df_sat_g12_cname
# Out:
#                  Enroll12  NumTSTTakr12  NumERWBenchmark12  \
# CName
# Alameda             17567          5946               4566
# Amador                305            53                 44
# Butte                2551           551                453
# Calaveras             451            90                 81
# Colusa                339            74                 39
# Contra Costa        14593          5412               3798
# Del Norte             363            72                 50
# El Dorado            2226           604                547
# Fresno              14299          4070               2664
# Glenn                 500            90                 58
# Humboldt             1342           300                250
# Imperial             3168           775                540
# Inyo                  548            88                 47
# Kern                14229          3793               2334
# Kings                2004           443                290
# ...

# %%
df_sat_g12_cname['Percent_Test_Takers'] = np.round((df_sat_g12_cname['NumTSTTakr12']/df_sat_g12_cname['Enroll12'])*100,2)

# %%
df_sat_g12_cname.head()
# Out:
#            Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  \
# CName
# Alameda       17567          5946               4566                3623
# Amador          305            53                 44                  35
# Butte          2551           551                453                 349
# Calaveras       451            90                 81                  60
# Colusa          339            74                 39                  15
#
#            TotNumBothBenchmark12  PctERWBenchmark12  PctMathBenchmark12  \
# CName
# Alameda                     3458              76.79               60.93
# Amador                        33              83.02               66.04
# Butte                        332              82.21               63.34
# Calaveras                     60              90.00               66.67
# Colusa                        14              52.70               20.27
#
#            PctBothBenchmark12  Percent_Test_Takers
# CName
# ...

# %%
df_sat_g12_cname[['Enroll12', 'NumTSTTakr12','TotNumBothBenchmark12','PctBothBenchmark12', 'Percent_Test_Takers']].head()
# Out:
#            Enroll12  NumTSTTakr12  TotNumBothBenchmark12  PctBothBenchmark12  \
# CName
# Alameda       17567          5946                   3458               58.16
# Amador          305            53                     33               62.26
# Butte          2551           551                    332               60.25
# Calaveras       451            90                     60               66.67
# Colusa          339            74                     14               18.92
#
#            Percent_Test_Takers
# CName
# Alameda                  33.85
# Amador                   17.38
# Butte                    21.60
# Calaveras                19.96
# Colusa                   21.83

# %%
df_sat_g12_cname.columns
# Out:
# Index(['Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12', 'NumMathBenchmark12',
#        'TotNumBothBenchmark12', 'PctERWBenchmark12', 'PctMathBenchmark12',
#        'PctBothBenchmark12', 'Percent_Test_Takers'],
#       dtype='object')

# %%
### Top 10 of Percent of Test Takers Grade 12 in each State
sns.set_style('whitegrid')
df_sat_g12_cname['Percent_Test_Takers'].sort_values(ascending=False)[:10].plot(kind='bar',figsize=(10,5),color='salmon',fontsize=12)
plt.title('G12 : Top 10 of Percent of Test Takers in each City\n',fontsize=15)
plt.xlabel('City Name')
plt.ylabel('Percent of Test Takers')
plt.xticks(rotation=30);

# %%
df_sat_g12_cname['Diff_Test'] = df_sat_g12_cname['Enroll12'] - df_sat_g12_cname['NumTSTTakr12']

# %%
df_sat_g12_cname.head()
# Out:
#            Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  \
# CName
# Alameda       17567          5946               4566                3623
# Amador          305            53                 44                  35
# Butte          2551           551                453                 349
# Calaveras       451            90                 81                  60
# Colusa          339            74                 39                  15
#
#            TotNumBothBenchmark12  PctERWBenchmark12  PctMathBenchmark12  \
# CName
# Alameda                     3458              76.79               60.93
# Amador                        33              83.02               66.04
# Butte                        332              82.21               63.34
# Calaveras                     60              90.00               66.67
# Colusa                        14              52.70               20.27
#
#            PctBothBenchmark12  Percent_Test_Takers  Diff_Test
# CName
# ...

# %%
df_sat_g12_cname[['Enroll12','NumTSTTakr12','Diff_Test']].sort_values(by = 'Enroll12',ascending=False)[:10].sort_values(by = 'Diff_Test' ,ascending=False)
# Out:
#                 Enroll12  NumTSTTakr12  Diff_Test
# CName
# Los Angeles       114618         48676      65942
# San Diego          42040         12872      29168
# Orange             41235         16061      25174
# San Bernardino     31635         10544      21091
# Riverside          34277         14070      20207
# Santa Clara        21656          6920      14736
# Sacramento         19540          6090      13450
# Alameda            17567          5946      11621
# Fresno             14299          4070      10229
# Contra Costa       14593          5412       9181

# %%
### Top 10 of Enrollment Grade 12 in each State
sns.set_style('whitegrid')
df_sat_g12_cname[['Enroll12','NumTSTTakr12','Diff_Test']].sort_values(by = 'Enroll12',ascending=False)[:10].sort_values(by = 'Diff_Test' ,ascending=False).plot(kind='bar',figsize=(12,5),width=0.7,fontsize=12,color=['#1BE9B1','#1BE9B1','salmon'],alpha=0.8)
plt.title('G12 : Top 10 Number of student in each City\n',fontsize=15)
plt.legend(['Student','Test_Takers','Diff'],loc=10)
plt.xlabel('City Name')
plt.ylabel('Number of student')
plt.xticks(rotation=30);

# %%
sns.set_style('whitegrid')
df_sat_g12_cname['Percent_Test_Takers'].sort_values(ascending=False)[-10:].sort_values(ascending=True).plot(kind='bar',figsize=(10,5),color='salmon',fontsize=12)
plt.title('G12 : The Last 10 of Percent of Test Takers in each City\n',fontsize=15)
plt.xlabel('City Name')
plt.ylabel('Percent of Test Takers')
plt.xticks(rotation=30);

# %%
df_sat_g12_cname_top10 = df_sat_g12_cname.sort_values(by ='Percent_Test_Takers', ascending=False)[:10]
df_sat_g12_cname_top10
# Out:
#                 Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  \
# CName
# San Francisco       4447          2256               1579                1380
# San Mateo           7235          3113               2410                1945
# Los Angeles       114618         48676              30081               19791
# Ventura            10750          4534               2815                2068
# Riverside          34277         14070               8572                5121
# Orange             41235         16061              11463                8971
# Contra Costa       14593          5412               3798                2814
# Marin               2647           965                855                 674
# Alameda            17567          5946               4566                3623
# San Bernardino     31635         10544               7014                4368
#
#                 TotNumBothBenchmark12  PctERWBenchmark12  PctMathBenchmark12  \
# CName
# ...

# %%
avg_per_top10_g12 = df_sat_g12_cname_top10.PctBothBenchmark12.mean()
avg_per_top10_g12
# Out:
# 49.968

# %%
df_sat_g12_cname_top10[['NumERWBenchmark12','NumMathBenchmark12','TotNumBothBenchmark12']].plot(kind='bar',figsize=(12,5),fontsize=10)
plt.ylabel('Number of Test Takers')
plt.title('G12 : Summary Top 10 of Test Takers(%) in California\n',fontsize=15)
plt.xticks(rotation=30);

# %%
df_sat_g12_cname_top10[['PctERWBenchmark12', 'PctMathBenchmark12','PctBothBenchmark12']].plot(kind='bar',figsize=(12,5),fontsize=10)
plt.axhline(avg_per_top10_g12,color='r',lw=2,linestyle='--',alpha=0.6,label='Mean of PctBothBenchmark12')
plt.ylabel('Percent of Test Takers who met the Benchmark')
plt.xlabel('City Name')
plt.xticks(rotation=30);
plt.title('G12 : Summary Top 10 of Test Takers(%) by SAT score in California\n',fontsize=15)
plt.legend();

# %%
df_sat_g12_cname_top10[['PctBothBenchmark12']].plot(kind='bar',figsize=(12,5),fontsize=10,color='#1BE9B1',alpha=0.8)
plt.axhline(avg_per_top10_g12,color='r',lw=2,linestyle='--',alpha=0.6,label='Mean of PctBothBenchmark12')
plt.ylabel('Percent of Test Takers who met the Benchmark')
plt.xlabel('City Name')
plt.xticks(rotation=30);
plt.title('G12 : Summary Top 10 of Test Takers(%) by SAT score in California\n',fontsize=15)
plt.legend();

# %%
df_sat_g12_cname_last10 = df_sat_g12_cname.sort_values(by ='Percent_Test_Takers', ascending=False)[-10:].sort_values(by ='Percent_Test_Takers', ascending=True)
df_sat_g12_cname_last10
# Out:
#           Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  \
# CName
# Mono           420            37                 32                  21
# Nevada        1869           186                159                 131
# Tehama         688            91                 69                  53
# Tuolumne       518            80                 66                  48
# Inyo           548            88                 47                  31
# Amador         305            53                 44                  35
# Shasta        2161           386                330                 256
# Glenn          500            90                 58                  27
# Yuba           977           178                140                  91
# Modoc           87            16                 12                   9
#
#           TotNumBothBenchmark12  PctERWBenchmark12  PctMathBenchmark12  \
# CName
# Mono                         21              86.49               56.76
# ...

# %%
df_sat_g12_cname_last10[['PctBothBenchmark12']].plot(kind='bar',figsize=(12,5),fontsize=10,color='#1BE9B1',alpha=0.8)
plt.axhline(avg_per_top10_g12,color='r',lw=2,linestyle='--',alpha=0.6,label='Mean of PctBothBenchmark12')
plt.ylabel('Percent of Test Takers who met the Benchmark')
plt.xlabel('City Name')
plt.xticks(rotation=30);
plt.title('G12 : Summary The Last 10 of Test Takers(%) by SAT score in California\n',fontsize=15)
plt.legend();
